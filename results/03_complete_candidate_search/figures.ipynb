# %%
# !pip install plotly

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.colors as pc
import pandas as pd
import numpy as np

# %%
import plotly.io as pio
pio.renderers.default = "png"

# %% [markdown]
# ## 5000 Infection recall

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.767, 0.826, 0.869, 0.909],
    mode='lines+markers',
    name='due_202203',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.803, 0.91, 0.945, 0.967],
    mode='lines+markers',
    name='nrw_202203',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.914, 0.971, 0.985, 0.99],
    mode='lines+markers',
    name='due_2022',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.942, 0.979, 0.993, 0.995],
    mode='lines+markers',
    name='nrw_2022',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.update_layout(
    width=1200,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Calculation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        itemwidth=100,
        x=0.6,
        y=0.1,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)
fig.show()

# %% [markdown]
# ## 5000 Commnunity ARI

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.275, 0.263, 0.333, 0.336],
    mode='lines+markers',
    name='due_202203',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.268, 0.406, 0.544, 0.624],
    mode='lines+markers',
    name='nrw_202203',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.378, 0.537, 0.619, 0.675],
    mode='lines+markers',
    name='due_2022',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.423, 0.601, 0.77, 0.853],
    mode='lines+markers',
    name='nrw_2022',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Calculation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        itemwidth=80,
        x=0.1,
        y=0.95,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)
fig.show()
fig.write_image("figures/community_ari_aggregates_5000.svg", width=1000, height=800)

# %% [markdown]
# ## 2500 Infection recall

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.763, 0.857, 0.914, 0.941],
    mode='lines+markers',
    name='due_202203',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.764, 0.867, 0.915, 0.947],
    mode='lines+markers',
    name='nrw_202203',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.905, 0.975, 0.986, 0.988],
    mode='lines+markers',
    name='due_2022',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.92, 0.976, 0.99, 0.995],
    mode='lines+markers',
    name='nrw_2022',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))


fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Computation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Infection recall',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        itemwidth=80,
        x=0.6,
        y=0.1,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)
fig.show()

# %% [markdown]
# ## 2500 Community ARI

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.48, 0.672, 0.696, 0.758],
    mode='lines+markers',
    name='due_202203',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.212, 0.323, 0.429, 0.511],
    mode='lines+markers',
    name='nrw_202203',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.408, 0.532, 0.541, 0.604],
    mode='lines+markers',
    name='due_2022',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.493, 0.692, 0.787, 0.872],
    mode='lines+markers',
    name='nrw_2022',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))


fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Calculation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        itemwidth=100,
        x=0.05,
        y= 0.98,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)

fig.show()
fig.write_image("figures/community_ari_aggregates_2500.svg", width=1000, height=800)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.17, 0.31, 0.365, 0.444],
    mode='lines+markers',
    name='due_202203',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.134, 0.26, 0.39, 0.464],
    mode='lines+markers',
    name='nrw_202203',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="dash"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.354, 0.524, 0.688, 0.774],
    mode='lines+markers',
    name='due_2022',
    line=dict(color=pc.qualitative.Plotly[0], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[0], size=10)
))

fig.add_trace(go.Scatter(
    x=[0.05, 0.1, 0.15, 0.2], y=[0.477, 0.701, 0.758, 0.786],
    mode='lines+markers',
    name='nrw_2022',
    line=dict(color=pc.qualitative.Plotly[2], width=5, dash="solid"),
    marker=dict(symbol='square', color=pc.qualitative.Plotly[2], size=10)
))

fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Calculation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        itemwidth=80,
        x=0.1,
        y=0.95,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)
fig.show()

# %% [markdown]
# ## Infection recall distribution for computation rates

# %%
depth_first_005 = [0.787, 0.722, 0.864, 0.918, 0.763, 0.764, 0.905, 0.92, 0.767, 0.803, 0.914, 0.942]
breadth_first_005 = [0.364, 0.406, 0.659, 0.768, 0.407, 0.422, 0.715, 0.772, 0.431, 0.469, 0.706, 0.809]
depth_first_01 = [0.854, 0.852, 0.934, 0.907, 0.857, 0.867, 0.975, 0.976, 0.826, 0.91, 0.971, 0.979]
breadth_first_01 = [0.55, 0.594, 0.801, 0.894, 0.597, 0.606, 0.849, 0.882, 0.591,  0.657, 0.843, 0.915]
depth_first_015 = [0.904, 0.925, 0.979, 0.987, 0.914, 0.915, 0.986, 0.99, 0.869, 0.945, 0.985, 0.993]
breadth_first_015 = [0.666, 0.714, 0.873, 0.929, 0.709, 0.713, 0.907, 0.932, 0.704, 0.756, 0.907, 0.956]
depth_first_02 = [0.935, 0.946, 0.986, 0.993, 0.941, 0.947, 0.988, 0.995, 0.909, 0.967, 0.99, 0.995]
breadth_first_02 = [0.747, 0.785, 0.911, 0.937, 0.786, 0.776, 0.933, 0.959, 0.786, 0.822, 0.933, 0.972]

data = pd.DataFrame({
    "computation_rate" : [0.05]*24 + [0.1]*24 + [0.15]*24 + [0.2]*24,
    "community_ari" : depth_first_005 + breadth_first_005 + depth_first_01 + breadth_first_01 + depth_first_015 + breadth_first_015 + depth_first_02 + breadth_first_02,
    "search_strategy": ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 
})

fig = px.box(data, y="community_ari", x="computation_rate", color="search_strategy", color_discrete_sequence=pc.qualitative.Plotly[3:])

fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Calculation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Infection recall',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        x=0.6,
        y=0.15,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)

fig.show()
fig.write_image("figures/depth_vs_breadth_infection_recall.svg", width=1000, height=800)

# %%
depth_first = depth_first_005 + depth_first_01 + depth_first_015 + depth_first_02 
breadth_first = breadth_first_005 + breadth_first_01 + breadth_first_015 + breadth_first_02
np.std(depth_first), np.std(breadth_first)
# Out:
# (np.float64(0.07195860777307249), np.float64(0.1666640208123317))

# %% [markdown]
# ## Community ARI distribution for computation rates

# %%
depth_first_005 = [0.17, 0.134, 0.354, 0.477, 0.48, 0.212, 0.408, 0.493, 0.275, 0.268, 0.378, 0.423]
breadth_first_005 = [0.175, 0.115, 0.318, 0.472, 0.23, 0.139, 0.319, 0.44, 0.177, 0.131, 0.308, 0.389]
depth_first_01 = [0.31, 0.26, 0.524, 0.701, 0.672, 0.323, 0.532, 0.692, 0.263, 0.406, 0.537, 0.601]
breadth_first_01 = [0.217, 0.212, 0.43, 0.549, 0.284, 0.226, 0.332, 0.558, 0.228, 0.188, 0.389, 0.492]
depth_first_015 = [0.365, 0.39, 0.688, 0.758, 0.696, 0.429, 0.541, 0.787, 0.333, 0.544, 0.619, 0.77]
breadth_first_015 = [0.266, 0.209, 0.43, 0.617, 0.316, 0.283, 0.461, 0.627, 0.263, 0.265, 0.441, 0.591]
depth_first_02 = [0.444, 0.464, 0.774, 0.786, 0.758, 0.511, 0.604, 0.872, 0.336, 0.624, 0.675, 0.853]
breadth_first_02 = [0.257,0.277, 0.528, 0.769, 0.375, 0.379, 0.547, 0.688, 0.294, 0.396, 0.472, 0.654]

data = pd.DataFrame({
    "computation_rate" : [0.05]*24 + [0.1]*24 + [0.15]*24 + [0.2]*24,
    "community_ari" : depth_first_005 + breadth_first_005 + depth_first_01 + breadth_first_01 + depth_first_015 + breadth_first_015 + depth_first_02 + breadth_first_02,
    "search_strategy": ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 
})

fig = px.box(data, y="community_ari", x="computation_rate", color="search_strategy", color_discrete_sequence=pc.qualitative.Plotly[3:])

fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Calculation rate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        x=0.05,
        y=0.95,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)

fig.show()
fig.write_image("figures/depth_vs_breadth_community_ari.svg", width=1000, height=800)

# %%
depth_first = depth_first_005 + depth_first_01 + depth_first_015 + depth_first_02 
breadth_first = breadth_first_005 + breadth_first_01 + breadth_first_015 + breadth_first_02
np.std(depth_first), np.std(breadth_first)
# Out:
# (np.float64(0.19026789866892652), np.float64(0.15882409551441565))

# %% [markdown]
# ## Community ARI distribution for aggregates

# %%
ds_due_202203_1250 = [0.17,0.31,0.365,0.444]
ds_nrw_202203_1250 = [0.134,0.26,0.39,0.464]
ds_due_2022_1250 = [0.354,0.524,0.688,0.774]
ds_nrw_2022_1250 = [0.477,0.701,0.758,0.786]

ds_due_202203_2500 = [0.48, 0.672, 0.696, 0.758]
ds_nrw_202203_2500 = [0.212, 0.323, 0.429, 0.511]
ds_due_2022_2500 = [0.408, 0.532, 0.541, 0.604]
ds_nrw_2022_2500= [0.493, 0.692, 0.787, 0.872]

ds_due_202203_5000 = [0.275, 0.263, 0.333, 0.336]
ds_nrw_202203_5000 = [0.268, 0.406, 0.544, 0.624]
ds_due_2022_5000 = [0.378, 0.537, 0.619, 0.675]
ds_nrw_2022_5000= [0.423, 0.601, 0.77, 0.853]

bs_due_202203_1250 = [0.175, 0.217, 0.266, 0.257]
bs_nrw_202203_1250 = [0.115, 0.212, 0.209, 0.277]
bs_due_2022_1250 = [0.318, 0.43, 0.43, 0.528]
bs_nrw_2022_1250 = [0.472,0.549,0.617,0.769]

bs_due_202203_2500 = [0.23, 0.284, 0.316,0.375]
bs_nrw_202203_2500 = [0.139,0.226, 0.283, 0.379]
bs_due_2022_2500 = [0.319,0.332,0.461,0.547]
bs_nrw_2022_2500= [0.44,0.558,0.627,0.688]

bs_due_202203_5000 = [0.177, 0.228, 0.263, 0.294]
bs_nrw_202203_5000 = [ 0.131, 0.188, 0.265,0.396]
bs_due_2022_5000 = [ 0.308,0.389,0.441,0.472]
bs_nrw_2022_5000 = [  0.389, 0.492,0.591,0.654]

data = pd.DataFrame({
    "community_ari" : ds_due_202203_1250 + ds_due_202203_2500 + ds_due_202203_5000 + bs_due_202203_1250 + bs_due_202203_2500 + bs_due_202203_2500 + 
    ds_nrw_202203_1250 + ds_nrw_202203_2500 + ds_nrw_202203_5000 + bs_nrw_202203_1250 + bs_nrw_202203_2500 + bs_nrw_202203_5000 + 
    ds_due_2022_1250 + ds_due_2022_2500 + ds_due_2022_5000 + bs_due_2022_1250 + bs_due_2022_2500 + bs_due_2022_5000 + 
    ds_nrw_2022_1250 + ds_nrw_2022_2500 + ds_nrw_2022_5000 + bs_nrw_2022_1250 + bs_nrw_2022_2500 + bs_nrw_2022_5000,
    "aggregate": ["due_202203"]*24 + ["nrw_202203"]*24 + ["due_2022"]*24 + ["nrw_2022"]*24,
    "search_strategy": ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12 + ["Depth search"]*12 + ["Breadth search"]*12
})

fig = px.box(data, y="community_ari", x="aggregate", color="search_strategy", color_discrete_sequence=pc.qualitative.Plotly[3:])

fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Aggregate',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        x=0.15,
        y=0.9,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)

fig.show()
fig.write_image("figures/depth_vs_breadth_aggregates_community_ari.svg", width=1000, height=800)

# %% [markdown]
# ## Community ARI distribution for aggregate sizes

# %%
ds_due_202203_1250 = [0.17,0.31,0.365,0.444]
ds_nrw_202203_1250 = [0.134,0.26,0.39,0.464]
ds_due_2022_1250 = [0.354,0.524,0.688,0.774]
ds_nrw_2022_1250 = [0.477,0.701,0.758,0.786]

ds_due_202203_2500 = [0.48, 0.672, 0.696, 0.758]
ds_nrw_202203_2500 = [0.212, 0.323, 0.429, 0.511]
ds_due_2022_2500 = [0.408, 0.532, 0.541, 0.604]
ds_nrw_2022_2500= [0.493, 0.692, 0.787, 0.872]

ds_due_202203_5000 = [0.275, 0.263, 0.333, 0.336]
ds_nrw_202203_5000 = [0.268, 0.406, 0.544, 0.624]
ds_due_2022_5000 = [0.378, 0.537, 0.619, 0.675]
ds_nrw_2022_5000= [0.423, 0.601, 0.77, 0.853]

bs_due_202203_1250 = [0.175, 0.217, 0.266, 0.257]
bs_nrw_202203_1250 = [0.115, 0.212, 0.209, 0.277]
bs_due_2022_1250 = [0.318, 0.43, 0.43, 0.528]
bs_nrw_2022_1250 = [0.472,0.549,0.617,0.769]

bs_due_202203_2500 = [0.23, 0.284, 0.316,0.375]
bs_nrw_202203_2500 = [0.139,0.226, 0.283, 0.379]
bs_due_2022_2500 = [0.319,0.332,0.461,0.547]
bs_nrw_2022_2500= [0.44,0.558,0.627,0.688]

bs_due_202203_5000 = [0.177, 0.228, 0.263, 0.294]
bs_nrw_202203_5000 = [ 0.131, 0.188, 0.265,0.396]
bs_due_2022_5000 = [ 0.308,0.389,0.441,0.472]
bs_nrw_2022_5000 = [  0.389, 0.492,0.591,0.654]

data = pd.DataFrame({
    "community_ari" : ds_due_202203_1250 + ds_nrw_202203_1250 + ds_due_2022_1250 + ds_nrw_2022_1250 + bs_due_202203_1250 + bs_nrw_202203_1250 + bs_due_2022_1250 + bs_nrw_2022_1250 +
    ds_due_202203_2500 + ds_nrw_202203_2500 + ds_due_2022_2500 + ds_nrw_2022_2500 + bs_due_202203_2500 + bs_nrw_202203_2500 + bs_due_2022_2500 + bs_nrw_2022_2500 +
    ds_due_202203_5000 + ds_nrw_202203_5000 + ds_due_2022_5000 + ds_nrw_2022_5000 + bs_due_202203_5000 + bs_nrw_202203_5000 + bs_due_2022_2500 + bs_nrw_2022_5000,
    "aggregate_size": ["1250"]*32 + ["2500"]*32 + ["5000"]*32,
    "search_strategy": ["Depth search"]*16 + ["Breadth search"]*16 + ["Depth search"]*16 + ["Breadth search"]*16 + ["Depth search"]*16 + ["Breadth search"]*16
})

fig = px.box(data, y="community_ari", x="aggregate_size", color="search_strategy", color_discrete_sequence=pc.qualitative.Plotly[3:])

fig.update_layout(
    width=1000,
    height=800,
    xaxis=dict(
        type='category',
        title=dict(
            text='Aggregate size',
            standoff=40
        ),
        tickangle=0
    ),
    yaxis=dict(
        title=dict(
            text='Community ARI',
            standoff=40
        ),
        tickangle=0
    ),
    legend_title="",
    template='presentation',
    font=dict(size=30),
    margin=dict(l=120,r=0,t=0,b=100),
    legend=dict(
        x=0.05,
        y=1.0,
        xanchor='left',
        orientation='v',
        borderwidth=0
    ),
)

fig.show()
fig.write_image("figures/depth_vs_breadth_sizes_community_ari.svg", width=1000, height=800)
